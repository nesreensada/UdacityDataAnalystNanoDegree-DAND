# %% [markdown]
# # Project: Investigatation of TMDb Movie Database
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# * The database under investigation is collected from The Movie Database (TMDb) with information about 10000 movies. The database contains the following attributes:
#     - id
#     - imdb_id
#     - homepage
#     - original_title
#     - overview
#     - popularity
#     - production_companies
#     - cast
#     - budget
#     - revenue
#     - director
#     - tagline
#     - keywords
#     - overview
#     - runtime
#     - genres
#     - release_date
#     - vote_count
#     - vote_average
#     - release_year
#     - budget_adj : same as budget but account for inflation over time.
#     - revenue_adj: same as budget but account for inflation over time.
#
#
# * Questions of interest:
#     - Which genres are most popular from year to year?
#     - What kinds of properties are associated with movies that have high revenues?

# %%
#import statemenets

import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
# In this section, I will load in the data, check for cleanliness, and then trim and clean the dataset for analysis.
#
# ### General Properties
# - Step 1: load data
# - Step 2: check the data types and for null values using .info() in pandas
# - Step 3: check for the value ranges and stats using .descibe() in pandas

# %%
# Load your data and print out a few lines. 
df = pd.read_csv("tmdb-movies.csv")
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# 0                      http://www.jurassicworld.com/   Colin Trevorrow
# 1                        http://www.madmaxmovie.com/     George Miller
# 2     http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 3  http://www.starwars.com/films/star-wars-episod...       J.J. Abrams
# 4                           http://www.furious7.com/         James Wan
#
#                          tagline      ...       \
# 0              The park is open.      ...
# 1             What a Lovely Day.      ...
# 2     One Choice Can Destroy You      ...
# 3  Every generation has a story.      ...
# 4            Vengeance Hits Home      ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
# 2  Beatrice Prior must confront her inner demons ...     119
# 3  Thirty years after defeating the Galactic Empi...     136
# 4  Deckard Shaw seeks revenge against Dominic Tor...     137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15       6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15       2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot     12/15/15       5292
# 4  Universal Pictures|Original Film|Media Rights ...       4/1/15       2947
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
# 3           7.5          2015  1.839999e+08  1.902723e+09
# 4           7.3          2015  1.747999e+08  1.385749e+09
#
# [5 rows x 21 columns]

# %% [markdown]
# From the above we can note that we have multi-valued columns: Genres, production_compaines, director and cast. this need to be handled in the cleaning section of the data

# %%
# check for null values and datatypes in the dataframe 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
# id                      10866 non-null int64
# imdb_id                 10856 non-null object
# popularity              10866 non-null float64
# budget                  10866 non-null int64
# revenue                 10866 non-null int64
# original_title          10866 non-null object
# cast                    10790 non-null object
# homepage                2936 non-null object
# director                10822 non-null object
# tagline                 8042 non-null object
# keywords                9373 non-null object
# overview                10862 non-null object
# runtime                 10866 non-null int64
# genres                  10843 non-null object
# production_companies    9836 non-null object
# release_date            10866 non-null object
# vote_count              10866 non-null int64
# vote_average            10866 non-null float64
# release_year            10866 non-null int64
# budget_adj              10866 non-null float64
# revenue_adj             10866 non-null float64
# dtypes: float64(4), int64(6), object(11)
# memory usage: 1.7+ MB

# %% [markdown]
# This data contains 21 columns and 10866 rows. it contain null values in the following columns: homepage, cast, director, tagline, keywords, genres, production companies. The datatype of the release_date needs to be changed to datetime instead of string.

# %%
#check for the value ranges and stats to look for erroneous values
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# std      575.619058      0.935142     12.812941  3.430616e+07  1.446325e+08
# min       10.000000      1.500000   1960.000000  0.000000e+00  0.000000e+00
# 25%       17.000000      5.400000   1995.000000  0.000000e+00  0.000000e+00
# 50%       38.000000      6.000000   2006.000000  0.000000e+00  0.000000e+00
# 75%      145.750000      6.600000   2011.000000  2.085325e+07  3.369710e+07
# max     9767.000000      9.200000   2015.000000  4.250000e+08  2.827124e+09

# %% [markdown]
# Erroneous values in the dataset can be seen in budget, revenue, budget_adj, revenue_adj since we can see the min value is 0. also for the popularity the max value 32.98 while Q3 is 0.7138 so this value needs to be normalized to get better results.

# %% [markdown]
# ### Data Cleaning
#
# In this section will handle rows with null values, wrong datatype and erroneous values
# - Step 1: Drop columns that are not related with our analysis. which are the following:tagline, overview, homepage, imdb_id,keywords, cast, revenue, budget, production_companies, director. note here that i dropped the revenue and budget because i will depend on budget_adj and revenue_adj columns that account for inflation.
# - Step 2: Remove erroneous values in budget_adj and revenue_adj
# - Step 3: Check if any missing values remain in genres
# - Step 4: Fix the datatype of release_date into date
# - Step 5: Normalize popularity column
# - Step 6: Handle multivalued genres column

# %% [markdown]
# #### Step 1: Drop columns that are not related with our analysis

# %%
# drop the columns not required in the analysis
df.drop(['tagline','overview','homepage','imdb_id','keywords','cast','production_companies','director'], axis = 1, inplace= True)
df.head()
# Out:
#        id  popularity     budget     revenue                original_title  \
# 0  135397   32.985763  150000000  1513528810                Jurassic World
# 1   76341   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  262500   13.112507  110000000   295238201                     Insurgent
# 3  140607   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  168259    9.335014  190000000  1506249360                     Furious 7
#
#    runtime                                     genres release_date  \
# 0      124  Action|Adventure|Science Fiction|Thriller       6/9/15
# 1      120  Action|Adventure|Science Fiction|Thriller      5/13/15
# 2      119         Adventure|Science Fiction|Thriller      3/18/15
# 3      136   Action|Adventure|Science Fiction|Fantasy     12/15/15
# 4      137                      Action|Crime|Thriller       4/1/15
#
#    vote_count  vote_average  release_year    budget_adj   revenue_adj
# 0        5562           6.5          2015  1.379999e+08  1.392446e+09
# 1        6185           7.1          2015  1.379999e+08  3.481613e+08
# 2        2480           6.3          2015  1.012000e+08  2.716190e+08
# 3        5292           7.5          2015  1.839999e+08  1.902723e+09
# 4        2947           7.3          2015  1.747999e+08  1.385749e+09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 13 columns):
# id                10866 non-null int64
# popularity        10866 non-null float64
# budget            10866 non-null int64
# revenue           10866 non-null int64
# original_title    10866 non-null object
# runtime           10866 non-null int64
# genres            10843 non-null object
# release_date      10866 non-null object
# vote_count        10866 non-null int64
# vote_average      10866 non-null float64
# release_year      10866 non-null int64
# budget_adj        10866 non-null float64
# revenue_adj       10866 non-null float64
# dtypes: float64(4), int64(6), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# now we have 13 columns and 10866 rows

# %% [markdown]
# #### Step 2: Remove erroneous values in budget_adj and revenue_adj

# %%
# drop budget or revenue with 0 value
df.drop(df[(df.budget ==0) | (df.revenue ==0)].index, axis = 0,inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3855 entries, 0 to 10848
# Data columns (total 13 columns):
# id                3855 non-null int64
# popularity        3855 non-null float64
# budget            3855 non-null int64
# revenue           3855 non-null int64
# original_title    3855 non-null object
# runtime           3855 non-null int64
# genres            3855 non-null object
# release_date      3855 non-null object
# vote_count        3855 non-null int64
# vote_average      3855 non-null float64
# release_year      3855 non-null int64
# budget_adj        3855 non-null float64
# revenue_adj       3855 non-null float64
# dtypes: float64(4), int64(6), object(3)
# memory usage: 421.6+ KB

# %% [markdown]
# the above shows that we have 13 columns and 3855 rows and we don't have null values any more.

# %%
df.describe()
# Out:
#                   id   popularity        budget       revenue      runtime  \
# count    3855.000000  3855.000000  3.855000e+03  3.855000e+03  3855.000000
# mean    39888.783398     1.191400  3.720183e+07  1.076589e+08   109.215824
# std     67213.815955     1.475002  4.220291e+07  1.765248e+08    19.922166
# min         5.000000     0.001117  1.000000e+00  2.000000e+00    15.000000
# 25%      6074.000000     0.462448  1.000000e+07  1.357645e+07    95.000000
# 50%     11322.000000     0.797298  2.400000e+07  4.479322e+07   106.000000
# 75%     38577.000000     1.368245  5.000000e+07  1.241530e+08   119.000000
# max    417859.000000    32.985763  4.250000e+08  2.781506e+09   338.000000
#
#         vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  3855.000000    3855.00000   3855.000000  3.855000e+03  3.855000e+03
# mean    527.611933       6.16786   2001.263294  4.423630e+07  1.370294e+08
# std     879.868374       0.79504     11.281989  4.480403e+07  2.160944e+08
# min      10.000000       2.20000   1960.000000  9.693980e-01  2.370705e+00
# 25%      71.000000       5.70000   1995.000000  1.309053e+07  1.834123e+07
# 50%     204.000000       6.20000   2004.000000  3.001558e+07  6.171861e+07
# 75%     580.000000       6.70000   2010.000000  6.061307e+07  1.632401e+08
# max    9767.000000       8.40000   2015.000000  4.250000e+08  2.827124e+09

# %% [markdown]
# Now looking at the budget column we can see that the min value is 1 while the Q1 is 1e7 which is a wide range with a large std of 1e7. So in order to investigate whether 1 is an outlier, we will try to look into values below 10M.

# %%
# check the budget stats for values below 10M [Q1 of the budget values]
df[df.budget < 1.000000e+07].budget.describe()
# Out:
# count    9.390000e+02
# mean     4.151066e+06
# std      2.697803e+06
# min      1.000000e+00
# 25%      1.993825e+06
# 50%      4.000000e+06
# 75%      6.400000e+06
# max      9.600000e+06
# Name: budget, dtype: float64

# %% [markdown]
# Observing the values below a budget of 10M, we have 939 rows. We can see that 25% of the data is below 2M. we still have a wide range of values below between 2M and 1.

# %%
# checking the budget stats for values below 2M [Q1 of movies with budget below 10M]
df[df.budget < 1.993825e+06].budget.describe()
# Out:
# count    2.350000e+02
# mean     7.476565e+05
# std      5.634518e+05
# min      1.000000e+00
# 25%      2.250000e+05
# 50%      7.770000e+05
# 75%      1.100000e+06
# max      1.987650e+06
# Name: budget, dtype: float64

# %% [markdown]
# around 59 rows are below 225k out of the total 3855 rows.

# %%
df[df.budget < 2.250000e+05].budget.describe()
# Out:
# count        59.000000
# mean      53476.457627
# std       65950.712119
# min           1.000000
# 25%          25.000000
# 50%       25000.000000
# 75%      100000.000000
# max      220000.000000
# Name: budget, dtype: float64

# %%
df[df.budget < 25000].head()
# Out:
#          id  popularity  budget  revenue  original_title  runtime  \
# 1354    985    0.331417   10000  7000000      Eraserhead       89
# 1733  22717    0.278387      75      134          Wanted      129
# 2398  39356    0.028456       3       43             Boy       87
# 2519  10397    0.352060      25       13  Angela's Ashes      145
# 2618  39964    0.090186       1      100    Lost & Found       95
#
#                                     genres release_date  vote_count  \
# 1354  Science Fiction|Fantasy|Horror|Drama      3/19/77         194
# 1733          Action|Comedy|Crime|Thriller      9/18/09          18
# 2398                          Drama|Comedy      2/14/10          26
# 2519                                 Drama     12/25/99          24
# 2618                        Comedy|Romance      4/23/99          14
#
#       vote_average  release_year    budget_adj   revenue_adj
# 1354           7.1          1977  35977.810326  2.518447e+07
# 1733           4.9          2009     76.230033  1.361977e+02
# 2398           7.3          2010      3.000000  4.300000e+01
# 2519           7.0          1999     32.726321  1.701769e+01
# 2618           4.8          1999      1.309053  1.309053e+02

# %% [markdown]
# One of the listed movie with a budget of 75 is wanted, When checked in Imdb the budget was 75M so this means that this value is not correct and maybe it is the same for other movies. so this proves that some movies might have wrong values so i will remove the movies values with budget less 25k

# %%
df.drop(df[(df.budget < 25000)].index, axis = 0,inplace= True)
df.head()
# Out:
#        id  popularity     budget     revenue                original_title  \
# 0  135397   32.985763  150000000  1513528810                Jurassic World
# 1   76341   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  262500   13.112507  110000000   295238201                     Insurgent
# 3  140607   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  168259    9.335014  190000000  1506249360                     Furious 7
#
#    runtime                                     genres release_date  \
# 0      124  Action|Adventure|Science Fiction|Thriller       6/9/15
# 1      120  Action|Adventure|Science Fiction|Thriller      5/13/15
# 2      119         Adventure|Science Fiction|Thriller      3/18/15
# 3      136   Action|Adventure|Science Fiction|Fantasy     12/15/15
# 4      137                      Action|Crime|Thriller       4/1/15
#
#    vote_count  vote_average  release_year    budget_adj   revenue_adj
# 0        5562           6.5          2015  1.379999e+08  1.392446e+09
# 1        6185           7.1          2015  1.379999e+08  3.481613e+08
# 2        2480           6.3          2015  1.012000e+08  2.716190e+08
# 3        5292           7.5          2015  1.839999e+08  1.902723e+09
# 4        2947           7.3          2015  1.747999e+08  1.385749e+09

# %%
df.describe()
# Out:
#                   id   popularity        budget       revenue      runtime  \
# count    3826.000000  3826.000000  3.826000e+03  3.826000e+03  3826.000000
# mean    39892.402771     1.197141  3.748379e+07  1.083883e+08   109.278097
# std     67313.696513     1.478847  4.223764e+07  1.769583e+08    19.868983
# min         5.000000     0.001117  2.500000e+04  2.000000e+00    26.000000
# 25%      6069.000000     0.465873  1.000000e+07  1.401073e+07    96.000000
# 50%     11292.500000     0.802740  2.400000e+07  4.565877e+07   106.000000
# 75%     38541.750000     1.379977  5.000000e+07  1.249111e+08   119.000000
# max    417859.000000    32.985763  4.250000e+08  2.781506e+09   338.000000
#
#         vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  3826.000000   3826.000000   3826.000000  3.826000e+03  3.826000e+03
# mean    530.794825      6.168662   2001.280972  4.457156e+07  1.379358e+08
# std     882.307624      0.795249     11.273625  4.480709e+07  2.166077e+08
# min      10.000000      2.200000   1960.000000  3.000000e+04  2.370705e+00
# 25%      72.000000      5.700000   1995.000000  1.337695e+07  1.878163e+07
# 50%     206.000000      6.200000   2004.000000  3.030653e+07  6.230869e+07
# 75%     582.000000      6.700000   2010.000000  6.076720e+07  1.646624e+08
# max    9767.000000      8.400000   2015.000000  4.250000e+08  2.827124e+09

# %% [markdown]
# Now the budget range from 25k-10M which is more reasonable than 1-10M. But looking closely we can see we have an issue with revenue where the min is 2 compared to 2.789 Max value.

# %%
# check the revenue window for values below 14M
df[df.revenue < 1.401073e+07].revenue.describe()
# Out:
# count    9.570000e+02
# mean     5.281333e+06
# std      4.408099e+06
# min      2.000000e+00
# 25%      1.021398e+06
# 50%      4.388563e+06
# 75%      9.237470e+06
# max      1.401069e+07
# Name: revenue, dtype: float64

# %% [markdown]
# 957 rows. a minimum value of 2 and Q1 of 1.02M dollar.

# %%
# check the revenue window for values below 1.02 dollars
df[df.revenue < 1.021398e+06].revenue.describe()
# Out:
# count    2.390000e+02
# mean     3.390444e+05
# std      3.141334e+05
# min      2.000000e+00
# 25%      5.556250e+04
# 50%      2.382270e+05
# 75%      5.939445e+05
# max      1.020921e+06
# Name: revenue, dtype: float64

# %% [markdown]
# we have 239 rows with minimum value of 2 and Q1 of 5.556250e+04 dollar revenue [almost 59 rows].

# %%
# check the revenue window for values below 5.556250e+04 dollars
df[df.revenue < 5.556250e+04].revenue.describe()
# Out:
# count       60.00000
# mean     19631.25000
# std      19365.32104
# min          2.00000
# 25%       2882.50000
# 50%      11798.50000
# 75%      32499.50000
# max      55125.00000
# Name: revenue, dtype: float64

# %% [markdown]
# We have 60 rows. half the values are below 11798.5 dollars

# %%
df[df.revenue < 11798.5].tail()
# Out:
#           id  popularity    budget  revenue  \
# 8226   48781    0.183034   6400000        6
# 8523    9431    0.578849  15000000        5
# 9332    1497    0.799449  25000000       78
# 10294  10285    0.504169   3000000       15
# 10307   2259    0.450208  25000000        6
#
#                                           original_title  runtime  \
# 8226                             Never Talk to Strangers       86
# 8523                                   Bordello of Blood       87
# 9332   Teenage Mutant Ninja Turtles II: The Secret of...       88
# 10294               Jason Goes to Hell: The Final Friday       87
# 10307                           The House of the Spirits      140
#
#                                                genres release_date  \
# 8226                                 Thriller|Romance     10/20/95
# 8523                                    Horror|Comedy      8/16/96
# 9332   Science Fiction|Adventure|Action|Comedy|Family      3/22/91
# 10294                                 Horror|Thriller      8/13/93
# 10307                                   Romance|Drama     10/19/93
#
#        vote_count  vote_average  release_year    budget_adj  revenue_adj
# 8226           15           4.5          1995  9.158188e+06     8.585801
# 8523           27           4.9          1996  2.085325e+07     6.951084
# 9332          161           6.0          1991  4.002732e+07   124.885242
# 10294          86           3.9          1993  4.528410e+06    22.642049
# 10307          52           6.7          1993  3.773675e+07     9.056820

# %% [markdown]
# Checking the house of spirit revenue is listed as 6.5M in imdb, so it is listed as a wrong value. so to be safe i will drop all revenues below 11798.

# %%
df.drop(df[(df.revenue < 11798)].index, axis = 0,inplace= True)
df.head()
# Out:
#        id  popularity     budget     revenue                original_title  \
# 0  135397   32.985763  150000000  1513528810                Jurassic World
# 1   76341   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  262500   13.112507  110000000   295238201                     Insurgent
# 3  140607   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  168259    9.335014  190000000  1506249360                     Furious 7
#
#    runtime                                     genres release_date  \
# 0      124  Action|Adventure|Science Fiction|Thriller       6/9/15
# 1      120  Action|Adventure|Science Fiction|Thriller      5/13/15
# 2      119         Adventure|Science Fiction|Thriller      3/18/15
# 3      136   Action|Adventure|Science Fiction|Fantasy     12/15/15
# 4      137                      Action|Crime|Thriller       4/1/15
#
#    vote_count  vote_average  release_year    budget_adj   revenue_adj
# 0        5562           6.5          2015  1.379999e+08  1.392446e+09
# 1        6185           7.1          2015  1.379999e+08  3.481613e+08
# 2        2480           6.3          2015  1.012000e+08  2.716190e+08
# 3        5292           7.5          2015  1.839999e+08  1.902723e+09
# 4        2947           7.3          2015  1.747999e+08  1.385749e+09

# %%
df.describe()
# Out:
#                   id   popularity        budget       revenue      runtime  \
# count    3796.000000  3796.000000  3.796000e+03  3.796000e+03  3796.000000
# mean    39704.035827     1.202594  3.766695e+07  1.092448e+08   109.393309
# std     67242.154029     1.483183  4.230713e+07  1.773928e+08    19.859426
# min         5.000000     0.001117  2.500000e+04  1.330800e+04    26.000000
# 25%      6015.750000     0.467870  1.000000e+07  1.456021e+07    96.000000
# 50%     11282.500000     0.808991  2.500000e+07  4.630034e+07   106.000000
# 75%     38356.250000     1.388066  5.000000e+07  1.262249e+08   119.000000
# max    417859.000000    32.985763  4.250000e+08  2.781506e+09   338.000000
#
#         vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  3796.000000   3796.000000   3796.000000  3.796000e+03  3.796000e+03
# mean    534.183614      6.172734   2001.243414  4.479191e+07  1.390259e+08
# std     884.875889      0.792529     11.293230  4.485523e+07  2.171134e+08
# min      10.000000      2.200000   1960.000000  3.000000e+04  1.388176e+04
# 25%      73.000000      5.700000   1995.000000  1.358189e+07  1.951956e+07
# 50%     207.500000      6.200000   2004.000000  3.039101e+07  6.314653e+07
# 75%     584.000000      6.700000   2010.000000  6.087715e+07  1.658074e+08
# max    9767.000000      8.400000   2015.000000  4.250000e+08  2.827124e+09

# %% [markdown]
# Now the budget range from 13.3k-2.78e9 which is more reasonable.

# %% [markdown]
# #### Step 3: Check if any missing values remain in genres

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3796 entries, 0 to 10848
# Data columns (total 13 columns):
# id                3796 non-null int64
# popularity        3796 non-null float64
# budget            3796 non-null int64
# revenue           3796 non-null int64
# original_title    3796 non-null object
# runtime           3796 non-null int64
# genres            3796 non-null object
# release_date      3796 non-null object
# vote_count        3796 non-null int64
# vote_average      3796 non-null float64
# release_year      3796 non-null int64
# budget_adj        3796 non-null float64
# revenue_adj       3796 non-null float64
# dtypes: float64(4), int64(6), object(3)
# memory usage: 415.2+ KB

# %% [markdown]
# we don't have null values in genres any more.and we have 3826

# %% [markdown]
# #### Step 4: Fix the datatype of release_date into datetime

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3796 entries, 0 to 10848
# Data columns (total 13 columns):
# id                3796 non-null int64
# popularity        3796 non-null float64
# budget            3796 non-null int64
# revenue           3796 non-null int64
# original_title    3796 non-null object
# runtime           3796 non-null int64
# genres            3796 non-null object
# release_date      3796 non-null object
# vote_count        3796 non-null int64
# vote_average      3796 non-null float64
# release_year      3796 non-null int64
# budget_adj        3796 non-null float64
# revenue_adj       3796 non-null float64
# dtypes: float64(4), int64(6), object(3)
# memory usage: 415.2+ KB

# %% [markdown]
# The release date is object so this we need to convert to datetime

# %%
# change the format of release date into datetime instead of a string
df['release_date'] = pd.to_datetime(df['release_date'], format='%m/%d/%y')

# %%
# confirm the change of datatype of release_date into datetime
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3796 entries, 0 to 10848
# Data columns (total 13 columns):
# id                3796 non-null int64
# popularity        3796 non-null float64
# budget            3796 non-null int64
# revenue           3796 non-null int64
# original_title    3796 non-null object
# runtime           3796 non-null int64
# genres            3796 non-null object
# release_date      3796 non-null datetime64[ns]
# vote_count        3796 non-null int64
# vote_average      3796 non-null float64
# release_year      3796 non-null int64
# budget_adj        3796 non-null float64
# revenue_adj       3796 non-null float64
# dtypes: datetime64[ns](1), float64(4), int64(6), object(2)
# memory usage: 415.2+ KB

# %% [markdown]
# The release date is a datetime now

# %% [markdown]
# #### Step 5: Normalize popularity column

# %%
df.popularity.describe()
# Out:
# count    3796.000000
# mean        1.202594
# std         1.483183
# min         0.001117
# 25%         0.467870
# 50%         0.808991
# 75%         1.388066
# max        32.985763
# Name: popularity, dtype: float64

# %% [markdown]
# The range of values for popularity column is 0-32.98. so in order to have a more consistent column values, i want to scale the values in range from 0-1 the values. since 75%-max value range between 1.37 and 32.98

# %%
df['normalized_popularity'] = (df.popularity - df.popularity.min()) / (df.popularity.max() - df.popularity.min())
df.head()
# Out:
#        id  popularity     budget     revenue                original_title  \
# 0  135397   32.985763  150000000  1513528810                Jurassic World
# 1   76341   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  262500   13.112507  110000000   295238201                     Insurgent
# 3  140607   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  168259    9.335014  190000000  1506249360                     Furious 7
#
#    runtime                                     genres release_date  \
# 0      124  Action|Adventure|Science Fiction|Thriller   2015-06-09
# 1      120  Action|Adventure|Science Fiction|Thriller   2015-05-13
# 2      119         Adventure|Science Fiction|Thriller   2015-03-18
# 3      136   Action|Adventure|Science Fiction|Fantasy   2015-12-15
# 4      137                      Action|Crime|Thriller   2015-04-01
#
#    vote_count  vote_average  release_year    budget_adj   revenue_adj  \
# 0        5562           6.5          2015  1.379999e+08  1.392446e+09
# 1        6185           7.1          2015  1.379999e+08  3.481613e+08
# 2        2480           6.3          2015  1.012000e+08  2.716190e+08
# 3        5292           7.5          2015  1.839999e+08  1.902723e+09
# 4        2947           7.3          2015  1.747999e+08  1.385749e+09
#
#    normalized_popularity
# 0               1.000000
# 1               0.861577
# 2               0.397500
# 3               0.338703
# 4               0.282977

# %%
df.normalized_popularity.describe()
# Out:
# count    3796.000000
# mean        0.036425
# std         0.044966
# min         0.000000
# 25%         0.014151
# 50%         0.024492
# 75%         0.042048
# max         1.000000
# Name: normalized_popularity, dtype: float64

# %%
# drop popularity column 
df.drop('popularity',inplace=True,axis=1)
df.head()
# Out:
#        id     budget     revenue                original_title  runtime  \
# 0  135397  150000000  1513528810                Jurassic World      124
# 1   76341  150000000   378436354            Mad Max: Fury Road      120
# 2  262500  110000000   295238201                     Insurgent      119
# 3  140607  200000000  2068178225  Star Wars: The Force Awakens      136
# 4  168259  190000000  1506249360                     Furious 7      137
#
#                                       genres release_date  vote_count  \
# 0  Action|Adventure|Science Fiction|Thriller   2015-06-09        5562
# 1  Action|Adventure|Science Fiction|Thriller   2015-05-13        6185
# 2         Adventure|Science Fiction|Thriller   2015-03-18        2480
# 3   Action|Adventure|Science Fiction|Fantasy   2015-12-15        5292
# 4                      Action|Crime|Thriller   2015-04-01        2947
#
#    vote_average  release_year    budget_adj   revenue_adj  \
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
# 3           7.5          2015  1.839999e+08  1.902723e+09
# 4           7.3          2015  1.747999e+08  1.385749e+09
#
#    normalized_popularity
# 0               1.000000
# 1               0.861577
# 2               0.397500
# 3               0.338703
# 4               0.282977

# %% [markdown]
# #### Step 6: Handle multivalued genres column
# - seperate the genres column in a new dataframe and use id as an index for the new dataframe
# - merge the new dataframe with the old dateframe using the id column

# %%
# check the genre column in the dataframe 
df.genres.head()
# Out:
# 0    Action|Adventure|Science Fiction|Thriller
# 1    Action|Adventure|Science Fiction|Thriller
# 2           Adventure|Science Fiction|Thriller
# 3     Action|Adventure|Science Fiction|Fantasy
# 4                        Action|Crime|Thriller
# Name: genres, dtype: object

# %% [markdown]
# Genres is multivalued column seperated by (|).
# Step 6.a: extract the genre and id columns from the df while preserving the id as index

# %%
df.set_index('id')['genres']
# Out:
# id
# 135397          Action|Adventure|Science Fiction|Thriller
# 76341           Action|Adventure|Science Fiction|Thriller
# 262500                 Adventure|Science Fiction|Thriller
# 140607           Action|Adventure|Science Fiction|Fantasy
# 168259                              Action|Crime|Thriller
# 281957                   Western|Drama|Adventure|Thriller
# 87101           Science Fiction|Action|Thriller|Adventure
# 286217                    Drama|Adventure|Science Fiction
# 211672                  Family|Animation|Adventure|Comedy
# 150540                            Comedy|Animation|Family
# 206647                             Action|Adventure|Crime
# 76757            Science Fiction|Fantasy|Action|Adventure
# 264660                              Drama|Science Fiction
# 257344                      Action|Comedy|Science Fiction
# 99861                    Action|Adventure|Science Fiction
# 273248                        Crime|Drama|Mystery|Western
# 260346                              Crime|Action|Thriller
# 102899                   Science Fiction|Action|Adventure
# 150689                       Romance|Fantasy|Family|Drama
# 131634                      War|Adventure|Science Fiction
# 158852    Action|Family|Science Fiction|Adventure|Mystery
# 307081                                       Action|Drama
# 254128                              Action|Drama|Thriller
# 216015                                      Drama|Romance
# 318846                                       Comedy|Drama
# 177677                                             Action
# 214756                                             Comedy
# 207703                      Crime|Comedy|Action|Adventure
# 314365                             Drama|Thriller|History
# 294254                    Action|Science Fiction|Thriller
#                                ...
# 660                             Adventure|Action|Thriller
# 15121                          Drama|Family|Music|Romance
# 907                                     Drama|Romance|War
# 10338                             Action|Adventure|Comedy
# 2428                                        Drama|History
# 668                             Adventure|Action|Thriller
# 642                           History|Drama|Western|Crime
# 3116                                                Drama
# 576                                     Adventure|Western
# 621                                                 Music
# 579                                       Horror|Thriller
# 923                                                Horror
# 1924             Adventure|Fantasy|Action|Science Fiction
# 948                                       Horror|Thriller
# 8469                                               Comedy
# 11778                                           Drama|War
# 11327                                         Drama|Crime
# 123                             Drama|Animation|Adventure
# 4192                                              Mystery
# 17339                       Action|Adventure|War|Thriller
# 9584                                  Action|Comedy|Drama
# 11850             Horror|Thriller|Science Fiction|Mystery
# 24961      Adventure|Family|Fantasy|Music|Science Fiction
# 10766                        Action|Drama|Horror|Thriller
# 11837                           Adventure|Animation|Drama
# 396                                                 Drama
# 5780                                     Mystery|Thriller
# 6644                                       Action|Western
# 5923                   Action|Adventure|Drama|War|Romance
# 2161                            Adventure|Science Fiction
# Name: genres, Length: 3796, dtype: object

# %% [markdown]
# Step 6.b: split the resulting using str.split with expand option set to true  to return the values into multiple columns

# %%
df.set_index('id')['genres'].str.split('|', expand = True)
# Out:
#                       0                1                2                3  \
# id
# 135397           Action        Adventure  Science Fiction         Thriller
# 76341            Action        Adventure  Science Fiction         Thriller
# 262500        Adventure  Science Fiction         Thriller             None
# 140607           Action        Adventure  Science Fiction          Fantasy
# 168259           Action            Crime         Thriller             None
# 281957          Western            Drama        Adventure         Thriller
# 87101   Science Fiction           Action         Thriller        Adventure
# 286217            Drama        Adventure  Science Fiction             None
# 211672           Family        Animation        Adventure           Comedy
# 150540           Comedy        Animation           Family             None
# 206647           Action        Adventure            Crime             None
# 76757   Science Fiction          Fantasy           Action        Adventure
# 264660            Drama  Science Fiction             None             None
# 257344           Action           Comedy  Science Fiction             None
# 99861            Action        Adventure  Science Fiction             None
# 273248            Crime            Drama          Mystery          Western
# 260346            Crime           Action         Thriller             None
# 102899  Science Fiction           Action        Adventure             None
# 150689          Romance          Fantasy           Family            Drama
# 131634              War        Adventure  Science Fiction             None
# 158852           Action           Family  Science Fiction        Adventure
# 307081           Action            Drama             None             None
# 254128           Action            Drama         Thriller             None
# 216015            Drama          Romance             None             None
# 318846           Comedy            Drama             None             None
# 177677           Action             None             None             None
# 214756           Comedy             None             None             None
# 207703            Crime           Comedy           Action        Adventure
# 314365            Drama         Thriller          History             None
# 294254           Action  Science Fiction         Thriller             None
# ...                 ...              ...              ...              ...
# 660           Adventure           Action         Thriller             None
# 15121             Drama           Family            Music          Romance
# 907               Drama          Romance              War             None
# 10338            Action        Adventure           Comedy             None
# 2428              Drama          History             None             None
# 668           Adventure           Action         Thriller             None
# 642             History            Drama          Western            Crime
# 3116              Drama             None             None             None
# 576           Adventure          Western             None             None
# 621               Music             None             None             None
# 579              Horror         Thriller             None             None
# 923              Horror             None             None             None
# 1924          Adventure          Fantasy           Action  Science Fiction
# 948              Horror         Thriller             None             None
# 8469             Comedy             None             None             None
# 11778             Drama              War             None             None
# 11327             Drama            Crime             None             None
# 123               Drama        Animation        Adventure             None
# 4192            Mystery             None             None             None
# 17339            Action        Adventure              War         Thriller
# 9584             Action           Comedy            Drama             None
# 11850            Horror         Thriller  Science Fiction          Mystery
# 24961         Adventure           Family          Fantasy            Music
# 10766            Action            Drama           Horror         Thriller
# 11837         Adventure        Animation            Drama             None
# 396               Drama             None             None             None
# 5780            Mystery         Thriller             None             None
# 6644             Action          Western             None             None
# 5923             Action        Adventure            Drama              War
# 2161          Adventure  Science Fiction             None             None
#
#                       4
# id
# 135397             None
# 76341              None
# 262500             None
# 140607             None
# 168259             None
# 281957             None
# 87101              None
# 286217             None
# 211672             None
# 150540             None
# 206647             None
# 76757              None
# 264660             None
# 257344             None
# 99861              None
# 273248             None
# 260346             None
# 102899             None
# 150689             None
# 131634             None
# 158852          Mystery
# 307081             None
# 254128             None
# 216015             None
# 318846             None
# 177677             None
# 214756             None
# 207703             None
# 314365             None
# 294254             None
# ...                 ...
# 660                None
# 15121              None
# 907                None
# 10338              None
# 2428               None
# 668                None
# 642                None
# 3116               None
# 576                None
# 621                None
# 579                None
# 923                None
# 1924               None
# 948                None
# 8469               None
# 11778              None
# 11327              None
# 123                None
# 4192               None
# 17339              None
# 9584               None
# 11850              None
# 24961   Science Fiction
# 10766              None
# 11837              None
# 396                None
# 5780               None
# 6644               None
# 5923            Romance
# 2161               None
#
# [3796 rows x 5 columns]

# %% [markdown]
# Step 6.c: Stack results of the split into an index instead of columns

# %%
df.set_index('id')['genres'].str.split('|', expand = True).stack()
# Out:
# id
# 135397  0             Action
#         1          Adventure
#         2    Science Fiction
#         3           Thriller
# 76341   0             Action
#         1          Adventure
#         2    Science Fiction
#         3           Thriller
# 262500  0          Adventure
#         1    Science Fiction
#         2           Thriller
# 140607  0             Action
#         1          Adventure
#         2    Science Fiction
#         3            Fantasy
# 168259  0             Action
#         1              Crime
#         2           Thriller
# 281957  0            Western
#         1              Drama
#         2          Adventure
#         3           Thriller
# 87101   0    Science Fiction
#         1             Action
#         2           Thriller
#         3          Adventure
# 286217  0              Drama
#         1          Adventure
#         2    Science Fiction
# 211672  0             Family
#                   ...
# 9584    1             Comedy
#         2              Drama
# 11850   0             Horror
#         1           Thriller
#         2    Science Fiction
#         3            Mystery
# 24961   0          Adventure
#         1             Family
#         2            Fantasy
#         3              Music
#         4    Science Fiction
# 10766   0             Action
#         1              Drama
#         2             Horror
#         3           Thriller
# 11837   0          Adventure
#         1          Animation
#         2              Drama
# 396     0              Drama
# 5780    0            Mystery
#         1           Thriller
# 6644    0             Action
#         1            Western
# 5923    0             Action
#         1          Adventure
#         2              Drama
#         3                War
#         4            Romance
# 2161    0          Adventure
#         1    Science Fiction
# Length: 10158, dtype: object

# %% [markdown]
# Step 6.d: remove the second index [0 1 2 3 4] which resulted from the split for the genres column using reset_index with level set to 1.

# %%
df.set_index('id')['genres'].str.split('|', expand = True).stack().reset_index(1, drop = True)
# Out:
# id
# 135397             Action
# 135397          Adventure
# 135397    Science Fiction
# 135397           Thriller
# 76341              Action
# 76341           Adventure
# 76341     Science Fiction
# 76341            Thriller
# 262500          Adventure
# 262500    Science Fiction
# 262500           Thriller
# 140607             Action
# 140607          Adventure
# 140607    Science Fiction
# 140607            Fantasy
# 168259             Action
# 168259              Crime
# 168259           Thriller
# 281957            Western
# 281957              Drama
# 281957          Adventure
# 281957           Thriller
# 87101     Science Fiction
# 87101              Action
# 87101            Thriller
# 87101           Adventure
# 286217              Drama
# 286217          Adventure
# 286217    Science Fiction
# 211672             Family
#                ...
# 9584               Comedy
# 9584                Drama
# 11850              Horror
# 11850            Thriller
# 11850     Science Fiction
# 11850             Mystery
# 24961           Adventure
# 24961              Family
# 24961             Fantasy
# 24961               Music
# 24961     Science Fiction
# 10766              Action
# 10766               Drama
# 10766              Horror
# 10766            Thriller
# 11837           Adventure
# 11837           Animation
# 11837               Drama
# 396                 Drama
# 5780              Mystery
# 5780             Thriller
# 6644               Action
# 6644              Western
# 5923               Action
# 5923            Adventure
# 5923                Drama
# 5923                  War
# 5923              Romance
# 2161            Adventure
# 2161      Science Fiction
# Length: 10158, dtype: object

# %% [markdown]
# Step 6.e: create a dateframe with a new index for the new resulting column and id using reset_index

# %%
df.set_index('id')['genres'].str.split('|', expand = True).stack().reset_index(1, drop = True).reset_index(name = 'Genre')
# Out:
#            id            Genre
# 0      135397           Action
# 1      135397        Adventure
# 2      135397  Science Fiction
# 3      135397         Thriller
# 4       76341           Action
# 5       76341        Adventure
# 6       76341  Science Fiction
# 7       76341         Thriller
# 8      262500        Adventure
# 9      262500  Science Fiction
# 10     262500         Thriller
# 11     140607           Action
# 12     140607        Adventure
# 13     140607  Science Fiction
# 14     140607          Fantasy
# 15     168259           Action
# 16     168259            Crime
# 17     168259         Thriller
# 18     281957          Western
# 19     281957            Drama
# 20     281957        Adventure
# 21     281957         Thriller
# 22      87101  Science Fiction
# 23      87101           Action
# 24      87101         Thriller
# 25      87101        Adventure
# 26     286217            Drama
# 27     286217        Adventure
# 28     286217  Science Fiction
# 29     211672           Family
# ...       ...              ...
# 10128    9584           Comedy
# 10129    9584            Drama
# 10130   11850           Horror
# 10131   11850         Thriller
# 10132   11850  Science Fiction
# 10133   11850          Mystery
# 10134   24961        Adventure
# 10135   24961           Family
# 10136   24961          Fantasy
# 10137   24961            Music
# 10138   24961  Science Fiction
# 10139   10766           Action
# 10140   10766            Drama
# 10141   10766           Horror
# 10142   10766         Thriller
# 10143   11837        Adventure
# 10144   11837        Animation
# 10145   11837            Drama
# 10146     396            Drama
# 10147    5780          Mystery
# 10148    5780         Thriller
# 10149    6644           Action
# 10150    6644          Western
# 10151    5923           Action
# 10152    5923        Adventure
# 10153    5923            Drama
# 10154    5923              War
# 10155    5923          Romance
# 10156    2161        Adventure
# 10157    2161  Science Fiction
#
# [10158 rows x 2 columns]

# %%
# all the steps at once 
temp_df = df.set_index('id')['genres'].str.split('|', expand = True).stack().reset_index(1, drop = True).reset_index(name = 'Genre')
temp_df.head()
# Out:
#        id            Genre
# 0  135397           Action
# 1  135397        Adventure
# 2  135397  Science Fiction
# 3  135397         Thriller
# 4   76341           Action

# %%
# merge the temp_df with the original dataframe
df_final = pd.merge(df, left_on ='id', right = temp_df, right_on = 'id', how='inner')
df_final.head()
# Out:
#        id     budget     revenue      original_title  runtime  \
# 0  135397  150000000  1513528810      Jurassic World      124
# 1  135397  150000000  1513528810      Jurassic World      124
# 2  135397  150000000  1513528810      Jurassic World      124
# 3  135397  150000000  1513528810      Jurassic World      124
# 4   76341  150000000   378436354  Mad Max: Fury Road      120
#
#                                       genres release_date  vote_count  \
# 0  Action|Adventure|Science Fiction|Thriller   2015-06-09        5562
# 1  Action|Adventure|Science Fiction|Thriller   2015-06-09        5562
# 2  Action|Adventure|Science Fiction|Thriller   2015-06-09        5562
# 3  Action|Adventure|Science Fiction|Thriller   2015-06-09        5562
# 4  Action|Adventure|Science Fiction|Thriller   2015-05-13        6185
#
#    vote_average  release_year    budget_adj   revenue_adj  \
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           6.5          2015  1.379999e+08  1.392446e+09
# 2           6.5          2015  1.379999e+08  1.392446e+09
# 3           6.5          2015  1.379999e+08  1.392446e+09
# 4           7.1          2015  1.379999e+08  3.481613e+08
#
#    normalized_popularity            Genre
# 0               1.000000           Action
# 1               1.000000        Adventure
# 2               1.000000  Science Fiction
# 3               1.000000         Thriller
# 4               0.861577           Action

# %%
# drop the genres column from the dataframe 
df_final.drop('genres', axis = 1, inplace= True)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10168 entries, 0 to 10167
# Data columns (total 13 columns):
# id                       10168 non-null int64
# budget                   10168 non-null int64
# revenue                  10168 non-null int64
# original_title           10168 non-null object
# runtime                  10168 non-null int64
# release_date             10168 non-null datetime64[ns]
# vote_count               10168 non-null int64
# vote_average             10168 non-null float64
# release_year             10168 non-null int64
# budget_adj               10168 non-null float64
# revenue_adj              10168 non-null float64
# normalized_popularity    10168 non-null float64
# Genre                    10168 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(6), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# we have 10245 rows with 13 column.

# %%
# remove revenue and budget since i will use the adjusted value
df_final.drop(['revenue','budget'],inplace=True, axis=1)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10168 entries, 0 to 10167
# Data columns (total 11 columns):
# id                       10168 non-null int64
# original_title           10168 non-null object
# runtime                  10168 non-null int64
# release_date             10168 non-null datetime64[ns]
# vote_count               10168 non-null int64
# vote_average             10168 non-null float64
# release_year             10168 non-null int64
# budget_adj               10168 non-null float64
# revenue_adj              10168 non-null float64
# normalized_popularity    10168 non-null float64
# Genre                    10168 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(4), object(2)
# memory usage: 953.2+ KB

# %% [markdown]
# The final dataframe that will be used in the analysis will have 10245 rows and 11 columns

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis
#
# ### Research Question 1: Which genres are the most popular from year to year?
# Get for each year the most popular genre according to the highest popurlity:
#  - Step 1: this was acheived by ordering the data by popularity descending and release year ascending
#  - Step 2: grouping by the year then selecting the genre
#  - Step 3: pick the first value which corresponds to the genre with the max popularity

# %%
df_final.sort_values(['release_year', 'normalized_popularity'], ascending=[True, False]).groupby('release_year')['Genre'].first()
# Out:
# release_year
# 1960              Drama
# 1961          Adventure
# 1962          Adventure
# 1963             Action
# 1964          Adventure
# 1965          Adventure
# 1966              Drama
# 1967             Family
# 1968    Science Fiction
# 1969          Adventure
# 1970          Animation
# 1971    Science Fiction
# 1972              Drama
# 1973          Animation
# 1974              Drama
# 1975              Drama
# 1976              Crime
# 1977          Adventure
# 1978              Music
# 1979             Horror
# 1980          Adventure
# 1981          Adventure
# 1982    Science Fiction
# 1983          Adventure
# 1984             Action
# 1985          Adventure
# 1986             Horror
# 1987    Science Fiction
# 1988             Action
# 1989          Animation
# 1990             Action
# 1991            Romance
# 1992              Crime
# 1993            Romance
# 1994           Thriller
# 1995              Crime
# 1996             Action
# 1997              Drama
# 1998             Comedy
# 1999              Drama
# 2000             Action
# 2001          Adventure
# 2002          Adventure
# 2003          Adventure
# 2004          Adventure
# 2005          Adventure
# 2006            Fantasy
# 2007          Adventure
# 2008              Drama
# 2009             Action
# 2010             Action
# 2011             Action
# 2012    Science Fiction
# 2013          Animation
# 2014          Adventure
# 2015             Action
# Name: Genre, dtype: object

# %% [markdown]
# Across the years Adenture seem to be the most popular genre and to confirm this i will use the value_counts on the grouped data

# %%
# we can also look into the value counts 
# to see the genres that repeated the most across the years
popular_genres_groupedby_year = df_final.sort_values(['release_year', 'normalized_popularity'], ascending=[True, False]).groupby('release_year')['Genre'].first().reset_index()
popular_genres_groupedby_year.Genre.value_counts()
# Out:
# Adventure          17
# Action             10
# Drama               8
# Science Fiction     5
# Animation           4
# Crime               3
# Horror              2
# Romance             2
# Thriller            1
# Comedy              1
# Music               1
# Fantasy             1
# Family              1
# Name: Genre, dtype: int64

# %% [markdown]
# The most common genre across the years is Adenture followed by action while the least common across the years is family, Thriller, Comedy, Music, Fantasy, Family

# %% [markdown]
# ### Research Question 2: What kinds of properties are associated with movies that have high revenues?
# - Step 1: create a new column with groups of different revenues according to min, 25%, 50%, 75%, max
# - Step 2: check the attributes of high revenue movies
# - Step 3: check for each revenue level the following attributes: 'runtime','vote_average','normalized_popularity','budget_adj'.
#     - using mean for the above attributes
#     - bar plot for each variable
# - Step 4: check if movies with higher budgets has higher revenue:
#     - using scatter plot for the two attributes
#     - using pearson correlation
# - Step 5: check if movies with higher popularity has higher revenue:
#     - using scatter plot for the two attributes
#     - using pearson correlation
# - Step 6: check genres associated with high revenue
# - Step 7: check director associated with high revenue

# %%
# revenue range
df_final.revenue_adj.describe()
# Out:
# count    1.016800e+04
# mean     1.535897e+08
# std      2.333281e+08
# min      1.388176e+04
# 25%      2.173537e+07
# 50%      6.981383e+07
# 75%      1.856079e+08
# max      2.827124e+09
# Name: revenue_adj, dtype: float64

# %% [markdown]
# #### Step 1: create a new column with groups of different revenues according to min, 25%, 50%, 75%, max

# %%
# Bin edges that will be used to "cut" the data into groups
bin_edges = [1.388176e+04, 1.197769e+07, 7.042110e+07, 1.985220e+08, 2.827124e+09]

# %%
# Labels for the four revenue level groups
bin_names = ['Low','Medium','Moderately High','High' ]

# %%
#create the revenue_levels column
df_final['revenue_levels'] = pd.cut(df_final['revenue_adj'], bin_edges, labels=bin_names)
df_final.head()
# Out:
#        id      original_title  runtime release_date  vote_count  vote_average  \
# 0  135397      Jurassic World      124   2015-06-09        5562           6.5
# 1  135397      Jurassic World      124   2015-06-09        5562           6.5
# 2  135397      Jurassic World      124   2015-06-09        5562           6.5
# 3  135397      Jurassic World      124   2015-06-09        5562           6.5
# 4   76341  Mad Max: Fury Road      120   2015-05-13        6185           7.1
#
#    release_year    budget_adj   revenue_adj  normalized_popularity  \
# 0          2015  1.379999e+08  1.392446e+09               1.000000
# 1          2015  1.379999e+08  1.392446e+09               1.000000
# 2          2015  1.379999e+08  1.392446e+09               1.000000
# 3          2015  1.379999e+08  1.392446e+09               1.000000
# 4          2015  1.379999e+08  3.481613e+08               0.861577
#
#              Genre revenue_levels
# 0           Action           High
# 1        Adventure           High
# 2  Science Fiction           High
# 3         Thriller           High
# 4           Action           High

# %% [markdown]
# we can check for Jurassic park it has a 1.392446e9 and revenue level of high since it is more than Q3 which is 1.856079e+08

# %% [markdown]
# #### Step 2: check the attributes of high revenue movies

# %%
# quick view of the attributes and high revenue
df_final[['runtime','vote_average','normalized_popularity','budget_adj','revenue_levels']].query('revenue_levels == "High"').describe()
# Out:
#            runtime  vote_average  normalized_popularity    budget_adj
# count  2382.000000   2382.000000            2382.000000  2.382000e+03
# mean    117.945424      6.484425               0.076022  9.716208e+07
# std      23.466714      0.705130               0.080443  5.772068e+07
# min      78.000000      4.400000               0.003954  3.272632e+04
# 25%     100.000000      6.000000               0.035626  5.065377e+07
# 50%     115.000000      6.500000               0.055900  9.012052e+07
# 75%     131.000000      7.000000               0.089397  1.335582e+08
# max     248.000000      8.300000               1.000000  3.683713e+08

# %% [markdown]
# looking at the above we can see that high revenue movies have the following attributes:
# - mean run time 117.95 minutes
# - mean vote average 6.48
# - mean normalized popularity 0.076022
# - mean budget 9.712e7

# %% [markdown]
# #### Step 3: check for each revenue level the following attributes: 'runtime','vote_average','normalized_popularity','budget_adj'.

# %%
# check the attributes asscoiated with different revenue level
df_final.groupby('revenue_levels')['runtime','vote_average','normalized_popularity','budget_adj'].mean()
# Out:
#                     runtime  vote_average  normalized_popularity    budget_adj
# revenue_levels
# Low              103.143681      5.914080               0.016483  1.576685e+07
# Medium           106.202134      6.018168               0.023775  3.210179e+07
# Moderately High  111.132512      6.201306               0.038069  5.309176e+07
# High             117.945424      6.484425               0.076022  9.716208e+07

# %% [markdown]
# From the above we can see that higher revenue, have higher runtime, popularity, budget. everything is increasing with the level of revenue

# %%
# bar plot for mean runtime 
grouped_df_runtime = df_final.groupby(["revenue_levels"])['runtime'].mean()
grouped_df_runtime.plot(kind='bar',title = 'Average Runtime for Revenue Levels');
plt.xlabel("Revenue Level")
plt.ylabel("Average Runtime")
# Out:
# Text(0,0.5,u'Average Runtime')

# %%
# bar plot for mean vote_average
grouped_df_runtime = df_final.groupby(["revenue_levels"])['vote_average'].mean()
grouped_df_runtime.plot(kind='bar',title = 'Average Vote for Revenue Levels');
plt.xlabel("Revenue Level")
plt.ylabel("Average Vote")
# Out:
# Text(0,0.5,u'Average Vote')

# %%
# bar plot for mean popularity 
grouped_df_runtime = df_final.groupby(["revenue_levels"])['normalized_popularity'].mean()
grouped_df_runtime.plot(kind='bar',title = 'Average Normalized Popularity for Revenue Levels');
plt.xlabel("Revenue Level")
plt.ylabel("Average Normalized Popularity")
# Out:
# Text(0,0.5,u'Average Normalized Popularity')

# %%
# bar plot for mean budget 
grouped_df_runtime = df_final.groupby(["revenue_levels"])['budget_adj'].mean()
grouped_df_runtime.plot(kind='bar',title = 'Average Budget for Revenue Levels');
plt.xlabel("Revenue Level")
plt.ylabel("Average Budget")
# Out:
# Text(0,0.5,u'Average Budget')

# %% [markdown]
# #### Step 4: check if movies with higher budgets has higher revenue:

# %%
#create scatter plot for revenue vs budget 
df_final.plot(y='revenue_adj', x = 'budget_adj',kind = 'scatter');

# %%
# pearson correlation coefficent 
df_final['revenue_adj'].corr(df_final['budget_adj'],method='pearson')
# Out:
# 0.5602491796182587

# %% [markdown]
# In the scatter plot the correlation is not very clear but when we check the pearson correlation it is 0.56 so since this value range between 0-1. there is a correlation between the budget adn revenue

# %% [markdown]
# #### Step 6: check genres associated with high revenue

# %%
# get the genres count for high revenue using groupby and count
df_final.query('revenue_levels == "High"').groupby(['Genre'])['revenue_levels'].count()
# Out:
# Genre
# Action             337
# Adventure          309
# Animation          102
# Comedy             258
# Crime              104
# Drama              254
# Family             164
# Fantasy            151
# History             22
# Horror              43
# Music               26
# Mystery             62
# Romance            112
# Science Fiction    156
# Thriller           233
# War                 36
# Western             13
# Name: revenue_levels, dtype: int64

# %% [markdown]
# More movies with Action genre generate high revenue followed by adventure while less Western Genres are associated with high revenue

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions
#
# - In this work the dataset has be cleaned by handling null values, wrong datatype and erroneous values.
# - Looked into the following Questions:
#     - Which genres are most popular from year to year?
#     - What kinds of properties are associated with movies that have high revenues?
# - The results of the analysis were as follows:
#     - Adventure genre is the most common genre across the years followed by Action genre.
#     - higher revenue, have higher runtime, popularity, budget.
